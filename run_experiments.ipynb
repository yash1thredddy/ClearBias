# %%
# !pip install pandas
# !pip install openai
# !pip install google-generativeai
# !pip install pip install google-api-core
# !pip install grpcio
# !pip install pyyaml

# %%
from openai import OpenAI
import google.generativeai as genai
from google.api_core import exceptions
import pandas as pd
import requests
import time
import random
import os
import json
import yaml
from tqdm import tqdm

with open('config.yaml', 'r') as file:
    config = yaml.safe_load(file)

#DB_API_KEY = config.get('DEEPBRICKS_API_KEY', "")
DS_API_KEY = config.get('DEEPSEEK_API_KEY', "")
G_API_KEY = config.get('GEMINI_API_KEY', "")

#client_db = OpenAI(api_key=DB_API_KEY, base_url="https://api.deepbricks.ai/v1/")
client_ds = OpenAI(api_key=DS_API_KEY, base_url="https://api.deepseek.com")
genai.configure(api_key=G_API_KEY)

# %%
def wait_with_exponential_backoff(retries, maximum_backoff=64):
    delay = min((2 ** retries) + random.uniform(0, 1), maximum_backoff)
    print(f"Waiting for {delay:.2f} seconds before the next attempt...")
    time.sleep(delay)


def call_api_with_backoff(api_call, *args, **kwargs):
    retries = 0
    maximum_backoff = 64
    while True:
        try:
            return api_call(*args, **kwargs)
        except Exception as e:
            print(f"Unexpected error: {str(e)}. Applying exponential backoff...")
            wait_with_exponential_backoff(retries, maximum_backoff)
            retries += 1
            raise e
"""

def invoke_db(model_name, prompt):
    def api_call():
        return client_db.chat.completions.create(
            model=model_name,
            messages=[{"role": "user", "content": prompt}]
        )
    completion = call_api_with_backoff(api_call)
    return completion.choices[0].message.content
"""

def invoke_ds(prompt):
    def api_call():
        return client_ds.chat.completions.create(
            model="deepseek-chat",
            messages=[{"role": "user", "content": prompt}],
            stream=False
        )
    response = call_api_with_backoff(api_call)
    return response.choices[0].message.content


def invoke_gemini(prompt):
    def api_call():
        model = genai.GenerativeModel(model_name="gemini-2.0-flash")
        chat_session = model.start_chat(history=[])
        response = chat_session.send_message(prompt)
        return response
    response = call_api_with_backoff(api_call)
    return response.text


def invoke_ollama(model_name, prompt):
    url = "http://localhost:11434/api/chat"
    command_dict = {
        "model": model_name,
        "stream": False,
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }
    try:
        command_json = json.dumps(command_dict)
        prompt_invoke = requests.post(
            url, data=command_json, headers={"Content-Type": "application/json"}
        )
        prompt_invoke.raise_for_status()
        json_res = prompt_invoke.json()
        if 'message' in json_res and 'content' in json_res['message']:
            response = json_res['message']['content']
        else:
            print("Error: The response does not contain the 'message' or 'content' key.")
            response = None
    except requests.exceptions.RequestException as e:
        print(f"Connection error: {e}")
        response = None
        json_res = None
    return json_res, response


def process_all_jailbreak_prompts(input_base_dir, output_base_dir, models, categories):
    for model in models:
        model_name = model.upper()

        for task in os.listdir(input_base_dir):
            # Ignore hidden files/directories
            if task.startswith('.'):
                continue
            task_path = os.path.join(input_base_dir, task)
            if not os.path.isdir(task_path):
                continue

            for attack_name in os.listdir(task_path):
                if attack_name.startswith('.'):
                    continue
                attack_path = os.path.join(task_path, attack_name)
                if not os.path.isdir(attack_path):
                    continue

                csv_files = [
                    f for f in os.listdir(attack_path)
                    if not f.startswith('.') and f.endswith('.csv')
                ]
                if not csv_files:
                    print(f"No csv file found in {attack_path}")
                    continue

                for csv_file in csv_files:
                    file_path = os.path.join(attack_path, csv_file)
                    csv_base = os.path.splitext(csv_file)[0]
                    try:
                        df = pd.read_csv(file_path)
                    except Exception as e:
                        print(f"Error reading {file_path}: {e}")
                        continue

                    prompts_data = []
                    for _, row in df.iterrows():
                        prompt = row["PROMPT"]
                        bias_category = row["BIAS CATEGORY"] if "BIAS CATEGORY" in row else ""
                        prompts_data.append({
                            "PROMPT": prompt,
                            "BIAS CATEGORY": bias_category
                        })

                    out_dir = os.path.join(output_base_dir, model_name, task, attack_name)
                    os.makedirs(out_dir, exist_ok=True)
                    results = []

                    for prompt_data in prompts_data:
                        prompt = prompt_data["PROMPT"]
                        bias_category = prompt_data["BIAS CATEGORY"]
                        if bias_category.upper() in categories:
                            continue
                        # NOTE: Replace the models in the list below with the ones you will be testing via Ollama
                        if model.lower() == "deepseek":
                            response = invoke_ds(prompt)
                        elif model.lower() == "gemini":
                            response = invoke_gemini(prompt)
                        else:
                            print(f"Unsupported model: {model}")
                            continue  # Skip this iteration if the model is not supported

                        result = {
                            "MODEL": model_name,
                            "BIAS CATEGORY": bias_category,
                            "PROMPT": prompt,
                            "RESPONSE": response,
                        }
                        results.append(result)

                    if results:
                        output_file = os.path.join(out_dir, f"{model_name}_{csv_base}.csv")
                        df_out = pd.DataFrame(results)
                        df_out.to_csv(output_file, index=False, encoding="utf-8")
                        print(f"Saved {output_file} with {len(results)} responses")


def process_all_base_prompts(input_base_dir, output_base_dir, models):
    
    for model in models:
        model_name = model.upper()
    
        for file in os.listdir(input_base_dir):
            if file.startswith('.') or not file.endswith('.csv'):
                continue

            file_path = os.path.join(input_base_dir, file)
            csv_base = os.path.splitext(file)[0]

            try:
                df = pd.read_csv(file_path)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")
                continue

            prompts_data = []
            for _, row in df.iterrows():
                prompt = row["PROMPT"]
                bias_category = row["BIAS CATEGORY"] if "BIAS CATEGORY" in row else ""
                prompts_data.append({
                    "PROMPT": prompt,
                    "BIAS CATEGORY": bias_category
                })

            out_dir = os.path.join(output_base_dir, model_name)
            os.makedirs(out_dir, exist_ok=True)

            results = []
            for prompt_data in prompts_data:
                prompt = prompt_data["PROMPT"]
                bias_category = prompt_data["BIAS CATEGORY"]

                if model.lower() == "deepseek":
                    response = invoke_ds(prompt)
                elif model.lower() == "gemini":
                    response = invoke_gemini(prompt)
                else:
                    print(f"Unsupported model: {model}")
                    continue  # Skip this iteration if the model is not supported

                result = {
                    "MODEL": model_name,
                    "BIAS CATEGORY": bias_category,
                    "PROMPT": prompt,
                    "RESPONSE": response,
                }
                results.append(result)

            if results:
                output_file = os.path.join(out_dir, f"{model_name}_{csv_base}.csv")
                df_out = pd.DataFrame(results)
                df_out.to_csv(output_file, index=False, encoding="utf-8")
                print(f"Saved {output_file} with {len(results)} responses")

# %% [markdown]
# # **Base prompts**

# %%
models = ["deepseek", "gemini"]

print("Started")
start_time = time.time()
process_all_base_prompts("CLEAR-Bias/base_prompts", "results/base_prompts", models)
end_time = time.time()
total_time = (end_time - start_time) / 60
hours = total_time // 60
minutes = total_time % 60
print(f"Total time: {hours} hours and {minutes} minutes")
# Out:
# Started
# Saved results/base_prompts\DEEPSEEK\DEEPSEEK_base_prompts_CTO.csv with 100 responses
# Saved results/base_prompts\DEEPSEEK\DEEPSEEK_base_prompts_SC.csv with 100 responses
# Saved results/base_prompts\GEMINI\GEMINI_base_prompts_CTO.csv with 100 responses
# Saved results/base_prompts\GEMINI\GEMINI_base_prompts_SC.csv with 100 responses
# Total time: 0.0 hours and 35.0384477853775 minutes

# %% [markdown]
# # **Jailbreak prompts**

# %%
bias_category_no_attack = {"DEEPSEEK": []}

print("Started")
start_time = time.time()
for model in bias_category_no_attack:
    process_all_jailbreak_prompts("CLEAR-Bias/jailbreak_prompts", "results/jailbreak_prompts", models=[model], categories=bias_category_no_attack[model])
end_time = time.time()
total_time = (end_time - start_time) / 60
hours = total_time // 60
minutes = total_time % 60
print(f"Total time: {hours} hours and {minutes} minutes")
# Out:
# Started
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\machine_translation\DEEPSEEK_machine_translation_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\machine_translation\DEEPSEEK_machine_translation_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\machine_translation\DEEPSEEK_machine_translation_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\obfuscation\DEEPSEEK_obfuscation_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\obfuscation\DEEPSEEK_obfuscation_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\obfuscation\DEEPSEEK_obfuscation_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\prefix_injection\DEEPSEEK_prefix_injection_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\prefix_injection\DEEPSEEK_prefix_injection_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\prefix_injection\DEEPSEEK_prefix_injection_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\prompt_injection\DEEPSEEK_prompt_injection_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\prompt_injection\DEEPSEEK_prompt_injection_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\prompt_injection\DEEPSEEK_prompt_injection_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\refusal_suppression\DEEPSEEK_refusal_suppression_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\refusal_suppression\DEEPSEEK_refusal_suppression_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\refusal_suppression\DEEPSEEK_refusal_suppression_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\reward_incentive\DEEPSEEK_reward_incentive_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\reward_incentive\DEEPSEEK_reward_incentive_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\reward_incentive\DEEPSEEK_reward_incentive_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\role_playing\DEEPSEEK_role_playing_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\role_playing\DEEPSEEK_role_playing_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\choose_the_option\role_playing\DEEPSEEK_role_playing_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\DEEPSEEK\sentence_completion\machine_translation\DEEPSEEK_machine_translation_v1_SC.csv with 100 responses
# Unexpected error: Expecting value: line 10 column 1 (char 9). Applying exponential backoff...
# Waiting for 1.38 seconds before the next attempt...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 6
#       4 start_time = time.time()
#       5 for model in bias_category_no_attack:
# ----> 6     process_all_jailbreak_prompts("CLEAR-Bias/jailbreak_prompts", "results/jailbreak_prompts", models=[model], categories=bias_category_no_attack[model])
#       7 end_time = time.time()
#       8 total_time = (end_time - start_time) / 60
#
# Cell In[3], line 138, in process_all_jailbreak_prompts(input_base_dir, output_base_dir, models, categories)
#     136 # NOTE: Replace the models in the list below with the ones you will be testing via Ollama
#     137 if model.lower() == "deepseek":
# --> 138     response = invoke_ds(prompt)
#     139 elif model.lower() == "gemini":
#     140     response = invoke_gemini(prompt)
#
# Cell In[3], line 37, in invoke_ds(prompt)
#      31 def api_call():
#      32     return client_ds.chat.completions.create(
#      33         model="deepseek-chat",
#      34         messages=[{"role": "user", "content": prompt}],
#      35         stream=False
#      36     )
# ---> 37 response = call_api_with_backoff(api_call)
#      38 return response.choices[0].message.content
#
# Cell In[3], line 17, in call_api_with_backoff(api_call, *args, **kwargs)
#      15 wait_with_exponential_backoff(retries, maximum_backoff)
#      16 retries += 1
# ---> 17 raise e
#
# Cell In[3], line 12, in call_api_with_backoff(api_call, *args, **kwargs)
#      10 while True:
#      11     try:
# ---> 12         return api_call(*args, **kwargs)
#      13     except Exception as e:
#      14         print(f"Unexpected error: {str(e)}. Applying exponential backoff...")
#
# Cell In[3], line 32, in invoke_ds.<locals>.api_call()
#      31 def api_call():
# ---> 32     return client_ds.chat.completions.create(
#      33         model="deepseek-chat",
#      34         messages=[{"role": "user", "content": prompt}],
#      35         stream=False
#      36     )
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\resources\chat\completions\completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     886 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     887 def create(
#     888     self,
#    (...)    926     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     927 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     928     validate_response_format(response_format)
# --> 929     return self._post(
#     930         "/chat/completions",
#     931         body=maybe_transform(
#     932             {
#     933                 "messages": messages,
#     934                 "model": model,
#     935                 "audio": audio,
#     936                 "frequency_penalty": frequency_penalty,
#     937                 "function_call": function_call,
#     938                 "functions": functions,
#     939                 "logit_bias": logit_bias,
#     940                 "logprobs": logprobs,
#     941                 "max_completion_tokens": max_completion_tokens,
#     942                 "max_tokens": max_tokens,
#     943                 "metadata": metadata,
#     944                 "modalities": modalities,
#     945                 "n": n,
#     946                 "parallel_tool_calls": parallel_tool_calls,
#     947                 "prediction": prediction,
#     948                 "presence_penalty": presence_penalty,
#     949                 "reasoning_effort": reasoning_effort,
#     950                 "response_format": response_format,
#     951                 "seed": seed,
#     952                 "service_tier": service_tier,
#     953                 "stop": stop,
#     954                 "store": store,
#     955                 "stream": stream,
#     956                 "stream_options": stream_options,
#     957                 "temperature": temperature,
#     958                 "tool_choice": tool_choice,
#     959                 "tools": tools,
#     960                 "top_logprobs": top_logprobs,
#     961                 "top_p": top_p,
#     962                 "user": user,
#     963                 "web_search_options": web_search_options,
#     964             },
#     965             completion_create_params.CompletionCreateParamsStreaming
#     966             if stream
#     967             else completion_create_params.CompletionCreateParamsNonStreaming,
#     968         ),
#     969         options=make_request_options(
#     970             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971         ),
#     972         cast_to=ChatCompletion,
#     973         stream=stream or False,
#     974         stream_cls=Stream[ChatCompletionChunk],
#     975     )
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)   1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056     log.debug("Re-raising status error")
#    1057     raise self._make_status_error_from_response(err.response) from None
# -> 1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    1062     response=response,
#    1063     stream=stream,
#    1064     stream_cls=stream_cls,
#    1065     retries_taken=retries_taken,
#    1066 )
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\_base_client.py:1158, in SyncAPIClient._process_response(self, cast_to, options, response, stream, stream_cls, retries_taken)
#    1155 if bool(response.request.headers.get(RAW_RESPONSE_HEADER)):
#    1156     return cast(ResponseT, api_response)
# -> 1158 return api_response.parse()
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\_response.py:323, in APIResponse.parse(self, to)
#     320 if not self._is_sse_stream:
#     321     self.read()
# --> 323 parsed = self._parse(to=to)
#     324 if is_given(self._options.post_parser):
#     325     parsed = self._options.post_parser(parsed)
#
# File ~\Desktop\CS516\516\Lib\site-packages\openai\_response.py:265, in BaseAPIResponse._parse(self, to)
#     260     # If the API responds with content that isn't JSON then we just return
#     261     # the (decoded) text without performing any parsing so that you can still
#     262     # handle the response however you need to.
#     263     return response.text  # type: ignore
# --> 265 data = response.json()
#     267 return self._client._process_response_data(
#     268     data=data,
#     269     cast_to=cast_to,  # type: ignore
#     270     response=response,
#     271 )
#
# File ~\Desktop\CS516\516\Lib\site-packages\httpx\_models.py:832, in Response.json(self, **kwargs)
#     831 def json(self, **kwargs: typing.Any) -> typing.Any:
# --> 832     return jsonlib.loads(self.content, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 10 column 1 (char 9)

# %%
bias_category_no_attack = {"gemini": []}

print("Started")
start_time = time.time()
for model in bias_category_no_attack:
    process_all_jailbreak_prompts("CLEAR-Bias/jailbreak_prompts", "results/jailbreak_prompts", models=[model], categories=bias_category_no_attack[model])
end_time = time.time()
total_time = (end_time - start_time) / 60
hours = total_time // 60
minutes = total_time % 60
print(f"Total time: {hours} hours and {minutes} minutes")
# Out:
# Started
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\machine_translation\GEMINI_machine_translation_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\machine_translation\GEMINI_machine_translation_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\machine_translation\GEMINI_machine_translation_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\obfuscation\GEMINI_obfuscation_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\obfuscation\GEMINI_obfuscation_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\obfuscation\GEMINI_obfuscation_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\prefix_injection\GEMINI_prefix_injection_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\prefix_injection\GEMINI_prefix_injection_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\prefix_injection\GEMINI_prefix_injection_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\prompt_injection\GEMINI_prompt_injection_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\prompt_injection\GEMINI_prompt_injection_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\prompt_injection\GEMINI_prompt_injection_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\refusal_suppression\GEMINI_refusal_suppression_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\refusal_suppression\GEMINI_refusal_suppression_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\refusal_suppression\GEMINI_refusal_suppression_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\reward_incentive\GEMINI_reward_incentive_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\reward_incentive\GEMINI_reward_incentive_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\reward_incentive\GEMINI_reward_incentive_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\role_playing\GEMINI_role_playing_v1_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\role_playing\GEMINI_role_playing_v2_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\choose_the_option\role_playing\GEMINI_role_playing_v3_CTO.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\machine_translation\GEMINI_machine_translation_v1_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\machine_translation\GEMINI_machine_translation_v2_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\machine_translation\GEMINI_machine_translation_v3_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\obfuscation\GEMINI_obfuscation_v1_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\obfuscation\GEMINI_obfuscation_v2_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\obfuscation\GEMINI_obfuscation_v3_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\prefix_injection\GEMINI_prefix_injection_v1_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\prefix_injection\GEMINI_prefix_injection_v2_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\prefix_injection\GEMINI_prefix_injection_v3_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\prompt_injection\GEMINI_prompt_injection_v1_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\prompt_injection\GEMINI_prompt_injection_v2_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\prompt_injection\GEMINI_prompt_injection_v3_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\refusal_suppression\GEMINI_refusal_suppression_v1_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\refusal_suppression\GEMINI_refusal_suppression_v2_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\refusal_suppression\GEMINI_refusal_suppression_v3_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\reward_incentive\GEMINI_reward_incentive_v1_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\reward_incentive\GEMINI_reward_incentive_v2_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\reward_incentive\GEMINI_reward_incentive_v3_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\role_playing\GEMINI_role_playing_v1_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\role_playing\GEMINI_role_playing_v2_SC.csv with 100 responses
# Saved results/jailbreak_prompts\GEMINI\sentence_completion\role_playing\GEMINI_role_playing_v3_SC.csv with 100 responses
# Total time: 0.0 hours and 50.72461897134781 minutes
